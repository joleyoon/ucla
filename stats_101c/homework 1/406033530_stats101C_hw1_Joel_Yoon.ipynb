# %% [markdown]
# # Homework 1
# Date: 2025-10-02
#
# # Question 1
#
# ### a
#
# “__Sometimes you have to make the hardest climb to see the most beautiful sunrise.__ I read that
# once on an old lady’s decorative pillow, but it is really how I feel today. I’ve climbed a very weird and rocky
# mountain, and it was a pain in the ass, and my legs are tired, and I’m starving. But *the sun is rising over
# a sea of love and waffles and possibility*. So *I’m just gonna relax and take a deep breath and enjoy this view
# for as long as I possibly can.*” – Leslie Knope (from **Parks and Recreation**)
#
# ### b
#
# | Homework | Midterm | Final Exam | Final Project |
# |---:|---:|---:|---:|
# | 18% | 30% | 40% | 12% |
#
# ### c
#
# - 2024
#   - Fall
#     - INTRO-DATA ANALYSIS POL SCI 6
#     - INTRODCTN-PROBABLTY STATS 100A=
#     - PROGRAMMING WITH R STATS 20
#
# - 2025
#   - winter
#     - INTRO-MATH STATSSTATS 100B
#     - INT DATA ANALY REGRSTATS 101A
#     - INTRO-COMP STATS-RSTATS 102A
#
#   - spring
#     - MUSIC OF KOREAETHNMUS 91J
#     - LINEAR MODELSSTATS 100C
#     - DSGN&ANLY-EXPERIMNTSTATS 101B
#     - INTRO CMPTTN&OPTZTNSTATS 102B
#
#   - fall
#     - APPLD NUMRICL MTHDSMATH 151A
#     - INT REGR DATA MINNGSTATS 101C
#     - MONTE CARLO METHODSSTATS 102C
#
# ### d

# %%
knitr::include_graphics("cat.jpeg")

# %% [markdown]
# https://unsplash.com/photos/brown-tabby-kitten-sitting-on-floor-nKC772R_qog
#
# $$
# \begin{split} \mathbb{E}\left[(Y - \hat{Y})^2\right] &= \mathbb{E}\left[\left(f(X) + \epsilon - \hat{f}(X)\right)^2\right] \\ &= \underbrace{\left(f(X) - \hat{f}(X)\right)^2}_{\text{Reducible}} + \underbrace{\text{Var}(\epsilon)}_{\text{Irreducible}} \end{split}
# $$
#
# # Question 2
#
# ### a
# Outcome Variable: True or False, depending on if a defendant was arrested within 12 months
#
# Predictor Variable: The group a defendant was assigned to
#
# ### c
# inference problem; we want to see if the counseling program has a significant effect
#
# ### d
# classification; because the outcome of the inference is if the defendent was arrested within 12 months or not/true or false
#
# ### e
# An independent samples t-test would compare the means between 2 independent groups
#
# To use the t-test, the outcome variable needs to be continuous, while the predictor doesn't matter
#
# A t-test is primarily used for inference
#
# This would be a regression model.
#
# # Question 3
#
# ### a
# Supervised
#
# ### b
# Outcome: 5 areas in the brain
#
# Predictor: TEC_sum, Group, TSPO_genotype, THC, Tobacco, Sex
#
# ### c
# inference problem; the goal is to understand the relationship between trauma and neuroinflammation
#
# ### d
# regression model; because the predictor variables are numerical quantities, not categories
#
# # Question 4
#
# ### a
# Outcome: bought
#
# Predictor: user action sequence
#
# ### b
# supervised modeling task
#
# ### c
# prediction problem; model's primary goal is to accurately forecast a future outcome
#
# ### d
# classification model; it's if somewhat bought something or not - true or false
#
# # Question 5
#
# ### a
# unsupervised
#
# ### b
# Outcome: None
#
# Predictor: total actions and sequence of actions taken
#
# ### c
# inference problem; the purpose of the model would be to understand patterns in the data
#
# ### d
# neither; clustering
#
# # Question 6
#
# ### a
# outcome: number of items shipped per month
#
# predictor: time series data
#
# ### b
# supervised; there is a historical dataset with labeled ouctomes and predictors
#
# ### c
# Prediction; the model will be used to predict in the future
#
# ### d
# Regression; the outcome variable is continuous
#
# # Question 7
# Just to learn about the different machine learning models that can be used in industry
